# %%
import numpy as np
import cv2
import os
import random
from matplotlib import pyplot as plt
path = os.path.abspath(os.path.join('DATA'))
path = 'E:\Juyter Folder\BAI6\data'

def convert(path):
    image = cv2.imread(path)
    image.resize(48,48)
    return image
def Read_data(path):
    os.chdir(path)
    allfile = os.listdir('.')
    label = []
    train = []
    k = 0
    for file in allfile:
        path2 = os.path.join(path, file)
        os.chdir(path2)
        allname = os.listdir('.')
        for name in allname:
                path3 = os.path.join(path2, name)
                vt = convert(path3)
                train.append(vt)
                label.append(file)
    X_train = np.asarray(train)
    X_label = np.asarray(label)
    return X_train,X_label

# %%
X_train,X_label = Read_data(path)

# %%
def KNN(x,X_train,X_label):
    image = cv2.cvtColor(x,cv2.COLOR_BGR2GRAY)
    image.resize(48,48)
    d = np.abs(X_train - image)
    distance = []
    for i in d:
        distance.append(i.mean())
    mmin = np.argmin(distance)
    return X_label[mmin]

# %%
X_label.shape
# Out:
# (43,)

# %%
from mtcnn.mtcnn import MTCNN
import cv2
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
pathg = os.path.abspath(os.path.join('TEST'))
path1 = 'E:\Juyter Folder\BAI6\TEST\IMG_5326.jpg'
path2 = 'E:\Juyter Folder\BAI6\TEST\IMG_5326.jpg'
path3 = 'E:\Juyter Folder\BAI6\TEST\IMG_5326.jpg'
path4 = 'E:\Juyter Folder\BAI6\TEST\IMG_5326.jpg'
path5 = 'E:\Juyter Folder\BAI6\TEST\IMG_5326.jpg'
path6 = 'E:\Juyter Folder\BAI6\TEST\IMG_5326.jpg'
path7 = 'E:\Juyter Folder\BAI6\TEST\IMG_5326.jpg'
# tao ham xem anh
def show_image(array):
    plt.imshow(cv2.cvtColor(array, cv2.COLOR_BGR2RGB))
path = np.array([path1,path2,path3,path4,path5,path6,path7])
img  = []
for p in path:
    k = cv2.imread(p)
    img.append(k)
    
# nhan dang bang MTCNN
detector = MTCNN()
list_face = []
k = 1
for iimg in img:
    print(k)
    detect_bound = (detector.detect_faces(iimg))
    list_face = []
    for i in range(0,len(detect_bound)):
        list_face.append(detect_bound[i]['box'])
    print()
    for face in list_face:
        plt.figure(k)
        crop = iimg[face[1]:face[1]+face[3],face[0]:face[0]+face[2],:]
        ketqua = KNN(crop,X_train,X_label)
        print(ketqua)
        plt.suptitle(ketqua, fontsize=16)
        #show_image(crop)
        k += 1
# Out:
# 1
#
# TRUONGTX
# LOCTH
# LOCTH
# LOCTH
# QUANVM
# HOAISD
# LOCTH
# MINHHA
# LOCTH
# TULG
# HOAISD
# 12
#
# TRUONGTX
# LOCTH
# LOCTH
# LOCTH
# QUANVM
# HOAISD
# LOCTH
# MINHHA
# LOCTH
# TULG
# HOAISD
# 23
#
# TRUONGTX
# LOCTH
# LOCTH
# LOCTH
# QUANVM
# HOAISD
# LOCTH
# MINHHA
# LOCTH
# TULG
# HOAISD
# 34
#
# TRUONGTX
# LOCTH
# LOCTH
# LOCTH
# QUANVM
# HOAISD
# LOCTH
# MINHHA
# LOCTH
# TULG
# HOAISD
# 45
#
# TRUONGTX
# LOCTH
# LOCTH
# LOCTH
# QUANVM
# HOAISD
# LOCTH
# MINHHA
# LOCTH
# TULG
# HOAISD
# 56
#
# TRUONGTX
# LOCTH
# LOCTH
# LOCTH
# QUANVM
# HOAISD
# LOCTH
# MINHHA
# LOCTH
# TULG
# HOAISD
# 67
#
# TRUONGTX
# LOCTH
# LOCTH
# LOCTH
# QUANVM
# HOAISD
# LOCTH
# MINHHA
# LOCTH
# TULG
# HOAISD

# %%
def KNN(x,X_train,X_label):
    image = cv2.cvtColor(x,cv2.COLOR_BGR2GRAY)
    image.resize(48,48)
    d = np.abs(X_train - image)
    distance = []
    for i in d:
        distance.append(i.mean())
    mmin = np.argmin(distance)
    return X_label[mmin]
h = KNN(crop,X_train,X_label)
print(h)
# Out:
# HOAISD
